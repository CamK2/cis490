# %% [markdown]
# <a href="https://colab.research.google.com/github/CamK2/cis490/blob/main/Assignment_02_CIS490_(10pts).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##(3 pts) Short questions
#
# Fill in short definitions/answers for each of the following:
#
# **observation space** -  a set of values describing the environment state the agent has access to.
#
# **action space** -  the range of possible states the agent may perceive and the actions available to the agent.
#
# **agent** -  a digital entity(code) which can interact with the virtual environment to achieve a goal.
#
# For MountainCar,
# * Is the observation space continuous or discrete? Continuous for both position and velocity.
# * How many dimensions is it? One dimsension. The track is a vector with only two directions to move: forward or backward.
#
# * Is the action space continuous or discrete? Discrete: Left, Neutral, and Right.

# %% [markdown]
# ## (3pts) Open loop agent.
# In the following cell, implement your open loop agent. You must not use the observation return variable. I will run it ten times to determine the average number of iterations to reach the top. (The lowest average in the class gets a bonus point.)

# %%
# Run this cell once to allow playable videos to be created
# Make sure it says SUCCESS after running, or rerun.

# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# install some helper functions to allow playing render videos in colab
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

print('SUCCESS!')
# Out:
# SUCCESS!

# %%
# YOUR OPEN-LOOP AGENT GOES HERE (YOU SHOULD NOT USE observation FOR THE
# OPEN LOOP AGENT)
env = wrap_env(gym.make("MountainCar-v0"))
observation = env.reset()
# observation is a two dimensional tuple that contains the position and 
# speed. The initial position and speed is not (0,0) but rather there is
# a small random starting position and speed.

step_i = 0  # use this variable as a counter for each step taken

while True:    
    env.render()
  
    #--------------------------------------------
    # your agent goes here (change the code here)
    # currently the action is randomly sampled from the action space
    # Above line nullified

    if step_i < 8:
      action = 1
    else: action = 2
    
    if step_i > 25:
      action = 1

    if step_i > 30:
      action = 0

    if step_i > 60:
      action = 1

    if step_i > 65:
      action = 2
          
    #-------------------------------------------

    # The following line calls the environment simulator with the
    # specified action. It runs the physics simulator for one time
    # step, and returns the observation, reward, done, and info. 
    # For our purposes, we are only interested in observation and done.
    # done is a bool, that is true if the car reaches the flag and is
    # false otherwise. 
    observation, reward, done, info = env.step(action) 
    step_i = step_i + 1
 
    # if car reaches the flag, exit the loop
    if done: 
      break;

print('------------------------\nDONE')
print('# steps taken: ', step_i)
env.close()
show_video()
# Out:
# ------------------------
# DONE
# # steps taken:  118
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## (4pts) Closed-loop agent.
# In the following cell, implement your closed-loop agent. You must make use of the observation variable in a meaningful way. I will run it ten times to determine the average number of iterations to reach the top. (The lowest average in the class gets a bonus point.)

# %%
# CLOSED LOOP AGENT (use observation)
# Insert code for your closed loop agent here (i.e. you should use 
# observation for deciding your next action).
# To start out, copy and paste the entire code contents of the above cell here.

env = wrap_env(gym.make("MountainCar-v0"))
observation = env.reset()
# observation is a two dimensional tuple that contains the position and 
# speed. The initial position and speed is not (0,0) but rather there is
# a small random starting position and speed.

step_i = 0  # use this variable as a counter for each step taken

while True:    
    env.render()
  
    #--------------------------------------------
    # your agent goes here (change the code here)
    # currently the action is randomly sampled from the action space
    # Above line nullified

    if step_i == 1:
      observation = env.observation_space
    print (observation)

    
          
    #-------------------------------------------

    # The following line calls the environment simulator with the
    # specified action. It runs the physics simulator for one time
    # step, and returns the observation, reward, done, and info. 
    # For our purposes, we are only interested in observation and done.
    # done is a bool, that is true if the car reaches the flag and is
    # false otherwise. 
    observation, reward, done, info = env.step(action) 
    step_i = step_i + 1
 
    # if car reaches the flag, exit the loop
    if done: 
      break;

print('------------------------\nDONE')
print('# steps taken: ', step_i)
env.close()
show_video()
# Out:
# [-0.55522258  0.        ]
# Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)
# [-5.54513877e-01  4.71877517e-04]
# [-0.55381047  0.00070341]
# [-0.55288078  0.00092969]
# [-0.55173176  0.00114902]
# [-0.550372    0.00135977]
# [-0.54881165  0.00156035]
# [-0.54706238  0.00174927]
# [-0.54513729  0.0019251 ]
# [-0.54305076  0.00208652]
# [-0.54081843  0.00223233]
# [-0.53845701  0.00236142]
# [-0.53598419  0.00247282]
# [-0.5334185   0.00256569]
# [-0.53077917  0.00263933]
# [-0.528086    0.00269318]
# [-0.52535917  0.00272683]
# [-0.52261914  0.00274003]
# [-0.51988645  0.00273268]
# [-0.51718161  0.00270484]
# [-0.51452489  0.00265672]
# [-0.51193622  0.00258867]
# [-0.509435    0.00250122]
# [-0.50703998  0.00239502]
# [-0.50476909  0.00227088]
# [-0.50263936  0.00212974]
# [-0.50066671  0.00197264]
# [-0.49886592  0.00180079]
# [-0.49725046  0.00161546]
# [-0.4958324   0.00141806]
# [-0.49462235  0.00121005]
# [-0.49362935  0.000993  ]
# [-0.49286082  0.00076853]
# [-0.4923225   0.00053832]
# [-4.92018403e-01  3.04095747e-04]
# [-4.91950806e-01  6.75971229e-05]
# [-4.92120212e-01 -1.69406201e-04]
# [-4.92525357e-01 -4.05144670e-04]
# [-0.49316322 -0.00063786]
# [-0.49402902 -0.00086581]
# [-0.49511631 -0.00108729]
# [-0.49641696 -0.00130065]
# [-0.49792125 -0.00150429]
# [-0.49961792 -0.00169668]
# [-0.5014943  -0.00187638]
# [-0.50353634 -0.00204204]
# [-0.50572876 -0.00219242]
# [-0.50805514 -0.00232638]
# [-0.51049806 -0.00244291]
# [-0.5130392  -0.00254114]
# [-0.51565953 -0.00262033]
# [-0.51833939 -0.00267987]
# [-0.5210587  -0.00271931]
# [-0.52379706 -0.00273836]
# [-0.52653394 -0.00273687]
# [-0.5292488  -0.00271486]
# [-0.53192128 -0.00267249]
# [-0.53453136 -0.00261007]
# [-0.53705945 -0.00252809]
# [-0.53948662 -0.00242717]
# [-0.54179467 -0.00230805]
# [-0.54396633 -0.00217165]
# [-0.54598532 -0.00201899]
# [-0.54783653 -0.00185122]
# [-0.54950613 -0.00166959]
# [-0.55098161 -0.00147548]
# [-0.55225196 -0.00127034]
# [-0.55330767 -0.00105571]
# [-0.55414086 -0.00083319]
# [-0.5547453  -0.00060444]
# [-5.55116484e-01 -3.71183943e-04]
# [-5.55251637e-01 -1.35153198e-04]
# [-5.55149750e-01  1.01886649e-04]
# [-5.54811584e-01  3.38165778e-04]
# [-0.55423966  0.00057192]
# [-0.55343826  0.0008014 ]
# [-0.55241336  0.0010249 ]
# [-0.55117262  0.00124074]
# [-0.54972531  0.00144731]
# [-0.54808225  0.00164306]
# [-0.54625574  0.00182652]
# [-0.54425942  0.00199631]
# [-0.54210825  0.00215117]
# [-0.53981833  0.00228992]
# [-0.53740681  0.00241152]
# [-0.53489176  0.00251505]
# [-0.53229203  0.00259973]
# [-0.52962711  0.00266492]
# [-0.52691698  0.00271013]
# [-0.52418196  0.00273502]
# [-0.52144257  0.00273939]
# [-0.51871934  0.00272322]
# [-0.51603272  0.00268663]
# [-0.51340283  0.00262989]
# [-0.5108494   0.00255343]
# [-0.50839157  0.00245783]
# [-0.50604775  0.00234382]
# [-0.50383551  0.00221225]
# [-0.5017714   0.00206411]
# [-0.49987088  0.00190052]
# [-0.49814817  0.00172271]
# [-0.49661616  0.00153202]
# [-0.49528629  0.00132987]
# [-0.49416851  0.00111778]
# [-0.49327117  0.00089734]
# [-0.49260098  0.0006702 ]
# [-4.92162929e-01  4.38046723e-04]
# [-4.91960302e-01  2.02627202e-04]
# [-4.91994607e-01 -3.43052276e-05]
# [-4.92265588e-01 -2.70981524e-04]
# [-0.49277122 -0.00050563]
# [-0.49350773 -0.00073651]
# [-0.49446962 -0.00096189]
# [-0.4956497  -0.00118008]
# [-0.49703915 -0.00138945]
# [-0.49862759 -0.00158844]
# [-0.50040314 -0.00177555]
# [-0.50235251 -0.00194937]
# [-0.50446112 -0.00210861]
# [-0.50671319 -0.00225207]
# [-0.50909184 -0.00237865]
# [-0.51157926 -0.00248742]
# [-0.51415681 -0.00257755]
# [-0.51680517 -0.00264835]
# [-0.51950447 -0.0026993 ]
# [-0.52223448 -0.00273001]
# [-0.52497472 -0.00274024]
# [-0.52770464 -0.00272992]
# [-0.53040377 -0.00269913]
# [-0.53305186 -0.00264809]
# [-0.53562907 -0.00257721]
# [-0.53811607 -0.002487  ]
# [-0.54049422 -0.00237815]
# [-0.54274571 -0.00225149]
# [-0.54485368 -0.00210797]
# [-0.54680234 -0.00194866]
# [-0.54857712 -0.00177478]
# [-0.55016474 -0.00158762]
# [-0.55155332 -0.00138858]
# [-0.55273249 -0.00117917]
# [-0.55369343 -0.00096094]
# [-0.55442897 -0.00073554]
# [-5.54933614e-01 -5.04643473e-04]
# [-5.55203592e-01 -2.69978159e-04]
# [-5.55236889e-01 -3.32970256e-05]
# [-5.55033256e-01  2.03632712e-04]
# [-5.54594214e-01  4.39042035e-04]
# [-0.55392304  0.00067117]
# [-0.55302475  0.00089829]
# [-0.55190605  0.0011187 ]
# [-0.5505753   0.00133075]
# [-0.54904245  0.00153285]
# [-0.54731895  0.00172349]
# [-0.54541771  0.00190125]
# [-0.54335294  0.00206477]
# [-0.5411401   0.00221284]
# [-0.53879576  0.00234434]
# [-0.53633748  0.00245828]
# [-0.53378369  0.00255379]
# [-0.53115352  0.00263017]
# [-0.52846669  0.00268683]
# [-0.52574336  0.00272333]
# [-0.52300394  0.00273942]
# [-0.52026898  0.00273496]
# [-0.517559    0.00270998]
# [-0.51489431  0.00266469]
# [-0.5122949   0.00259941]
# [-0.50978025  0.00251465]
# [-0.50736921  0.00241104]
# [-0.50507985  0.00228937]
# [-0.5029293   0.00215055]
# [-0.50093368  0.00199562]
# [-0.49910791  0.00182577]
# [-0.49746566  0.00164225]
# [-0.49601921  0.00144645]
# [-0.49477937  0.00123984]
# [-0.4937554   0.00102397]
# [-0.49295497  0.00080044]
# [-0.49238403  0.00057093]
# [-4.92046866e-01  3.37165167e-04]
# [-4.91945987e-01  1.00879060e-04]
# [-4.92082148e-01 -1.36160243e-04]
# [-4.92454331e-01 -3.72182925e-04]
# [-0.49305976 -0.00060543]
# [-0.49389391 -0.00083415]
# [-0.49495055 -0.00105664]
# [-0.49622178 -0.00127124]
# [-0.49769812 -0.00147633]
# [-0.49936851 -0.00167039]
# [-0.50122047 -0.00185196]
# [-0.50324015 -0.00201967]
# [-0.50541241 -0.00217227]
# [-0.50772101 -0.0023086 ]
# [-0.51014865 -0.00242764]
# [-0.51267713 -0.00252848]
# [-0.51528751 -0.00261038]
# [-0.51796022 -0.00267271]
# [-0.52067522 -0.002715  ]
# [-0.52341214 -0.00273692]
# ------------------------
# DONE
# # steps taken:  200
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
