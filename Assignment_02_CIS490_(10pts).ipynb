# %% [markdown]
# <a href="https://colab.research.google.com/github/CamK2/cis490/blob/main/Assignment_02_CIS490_(10pts).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##(3 pts) Short questions
#
# Fill in short definitions/answers for each of the following:
#
# **observation space** -  a set of values describing the environment state the agent has access to.
#
# **action space** -  the range of possible states the agent may perceive and the actions available to the agent.
#
# **agent** -  a digital entity(code) which can interact with the virtual environment to achieve a goal.
#
# For MountainCar,
# * Is the observation space continuous or discrete? Continuous for both position and velocity.
# * How many dimensions is it? One dimsension. The track is a vector with only two directions to move: forward or backward.
#
# * Is the action space continuous or discrete? Discrete: Left, Neutral, and Right.

# %% [markdown]
# ## (3pts) Open loop agent.
# In the following cell, implement your open loop agent. You must not use the observation return variable. I will run it ten times to determine the average number of iterations to reach the top. (The lowest average in the class gets a bonus point.)

# %%
# Run this cell once to allow playable videos to be created
# Make sure it says SUCCESS after running, or rerun.

# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# install some helper functions to allow playing render videos in colab
import gym
from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

"""
Utility functions to enable video recording of gym environment 
and displaying it.
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

print('SUCCESS!')
# Out:
# SUCCESS!

# %%
# YOUR OPEN-LOOP AGENT GOES HERE (YOU SHOULD NOT USE observation FOR THE
# OPEN LOOP AGENT)
env = wrap_env(gym.make("MountainCar-v0"))
observation = env.reset()
# observation is a two dimensional tuple that contains the position and 
# speed. The initial position and speed is not (0,0) but rather there is
# a small random starting position and speed.

step_i = 0  # use this variable as a counter for each step taken

while True:    
    env.render()
  
    #--------------------------------------------
    # your agent goes here (change the code here)
    # currently the action is randomly sampled from the action space
    # Above line nullified

    action = 2
    
    if step_i > 25:
      action = 1

    if step_i > 30:
      action = 0

    if step_i > 55:
      action = 1

    if step_i > 60:
      action = 2
          
    #-------------------------------------------

    # The following line calls the environment simulator with the
    # specified action. It runs the physics simulator for one time
    # step, and returns the observation, reward, done, and info. 
    # For our purposes, we are only interested in observation and done.
    # done is a bool, that is true if the car reaches the flag and is
    # false otherwise. 
    observation, reward, done, info = env.step(action) 
    step_i = step_i + 1
 
    # if car reaches the flag, exit the loop
    if done: 
      break;

print('------------------------\nDONE')
print('# steps taken: ', step_i)
env.close()
show_video()
# Out:
# ------------------------
# DONE
# # steps taken:  108
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ## (4pts) Closed-loop agent.
# In the following cell, implement your closed-loop agent. You must make use of the observation variable in a meaningful way. I will run it ten times to determine the average number of iterations to reach the top. (The lowest average in the class gets a bonus point.)

# %%
# CLOSED LOOP AGENT (use observation)
# Insert code for your closed loop agent here (i.e. you should use 
# observation for deciding your next action).
# To start out, copy and paste the entire code contents of the above cell here.

env = wrap_env(gym.make("MountainCar-v0"))
observation = env.reset()
# observation is a two dimensional tuple that contains the position and 
# speed. The initial position and speed is not (0,0) but rather there is
# a small random starting position and speed.

step_i = 0  # use this variable as a counter for each step taken

while True:    
    env.render()
  
    #--------------------------------------------
    # your agent goes here (change the code here)
    # currently the action is randomly sampled from the action space
    # Above line nullified

    # Observation[0] = Position
    # Observation[1] = Velocity
    # -0.47306 is lowest point on the track. Range: (-1.2, .5)

    action = 2

    if observation[0] > -.47 and observation[1] > 0 and 5 < step_i < 15:
      action = 0
    
    if observation[1] > 0:
      action = 2

    if observation[1] < 0:
      action = 0

    if observation[0] < -.8:
      action = 2
    
    print(observation[0]," ",observation[1])
    
          
    #-------------------------------------------

    # The following line calls the environment simulator with the
    # specified action. It runs the physics simulator for one time
    # step, and returns the observation, reward, done, and info. 
    # For our purposes, we are only interested in observation and done.
    # done is a bool, that is true if the car reaches the flag and is
    # false otherwise. 
    observation, reward, done, info = env.step(action) 
    step_i = step_i + 1
 
    # if car reaches the flag, exit the loop
    if done: 
      break;

print('------------------------\nDONE')
print('# steps taken: ', step_i)
env.close()
show_video()
# Out:
# -0.5592456956951106   0.0
# -0.5579788530903319   0.0012668426047787351
# -0.5554546168263681   0.0025242362639637827
# -0.551691825267436   0.00376279155893212
# -0.5467185851777008   0.004973240089735175
# -0.5405720855116446   0.006146499666056224
# -0.533298341025437   0.007273744486207583
# -0.5249518600642826   0.008346480961154439
# -0.5155952309975027   0.009356629066779963
# -0.5052986227477352   0.01029660824976747
# -0.49413919670753037   0.0111594260402048
# -0.4822004299926771   0.011938766714853272
# -0.46957135330404004   0.012629076688637036
# -0.4563457104414481   0.013225642862591907
# -0.44262105045678773   0.013724659984660386
# -0.4284977672333269   0.014123283223460853
# -0.41407810460973027   0.01441966262359661
# -0.3994651477291604   0.01461295688056985
# -0.3847618228411815   0.014703324887978923
# -0.37006992815505857   0.014691894686122895
# -0.3554892174771574   0.014580710677901194
# -0.3411165563099718   0.014372661167185632
# -0.3270451669944592   0.014071389315512611
# -0.31336397557216167   0.013681191422297526
# -0.30015706861580077   0.013206906956360892
# -0.2875032636370762   0.012653804978724613
# -0.2754757921306446   0.012027471506431596
# -0.26414209012063733   0.011333702010007253
# -0.25356368745202723   0.01057840266861012
# -0.24379618415847423   0.009767503293553
# -0.23488930011687847   0.008906884041595746
# -0.22688698287919906   0.00800231723767941
# -0.21982755801413492   0.007059424865064132
# -0.21374390641665703   0.006083651597477891
# -0.20866365375044552   0.005080252666211521
# -0.2046093583659585   0.004054295384487011
# -0.20159868557628222   0.0030106727896762843
# -0.19964455797591796   0.0019541276003642596
# -0.1987552734719588   0.0008892845039591697
# -0.1989345847983314   -0.0001793113263726079
# -0.20218173645484366   -0.003247151656512277
# -0.20848294376026413   -0.0063012073054204785
# -0.21781090213536353   -0.009327958375099402
# -0.23012386472312696   -0.012312962587763437
# -0.2453643508815138   -0.015240486158386836
# -0.26345758034822087   -0.01809322946670707
# -0.28430976103728506   -0.02085218068906417
# -0.30780639073753097   -0.02349662970024591
# -0.3338107612421599   -0.026004370504628962
# -0.3621628730640001   -0.028352111821840165
# -0.3926789743709324   -0.030516101306932344
# -0.4251519235826513   -0.03247294921171888
# -0.45935253698940237   -0.03420061340675104
# -0.4950320194308568   -0.0356794824414544
# -0.5319254903778977   -0.03689347094704089
# -0.5697565174588057   -0.037831027080908006
# -0.6082424667493649   -0.03848594929055915
# -0.6471003887805792   -0.0388579220312143
# -0.6860530956578473   -0.03895270687726819
# -0.7248350587660564   -0.038781963108209
# -0.7631977728030676   -0.03836271403701118
# -0.8009142874239469   -0.03771651462087931
# -0.8357826929401282   -0.034868405516181276
# -0.867637299536366   -0.031854606596237824
# -0.8963459406172735   -0.02870864108090746
# -0.9218062494453604   -0.02546030882808695
# -0.9439413657443966   -0.022135116299036216
# -0.9626954716727805   -0.018754105928383905
# -0.9780294800750998   -0.015334008402319368
# -0.9899171181285082   -0.011887638053408388
# -0.9983415772294003   -0.008424459100892026
# -1.0032928409882174   -0.004951263758817031
# -1.0047657591789225   -0.0014729181907051788
# -1.0027589051739703   0.00200685400495234
# -0.9972742347080508   0.005484670465919474
# -0.9883175506668976   0.008956684041153172
# -0.9758997674328742   0.012417783234023379
# -0.9600389544574076   0.015860812975466595
# -0.9407631176596135   0.019275836797794137
# -0.9181136449967678   0.022649472662845657
# -0.892149296258043   0.025964348738724843
# -0.8629505559183258   0.029198740339717127
# -0.8306240939709708   0.03232646194735495
# -0.7953069995369084   0.03531709443406238
# -0.7571703773493415   0.03813662218756692
# -0.7164218445722145   0.04074853277712698
# -0.6733064546851935   0.043115389887021
# -0.6281056255271803   0.0452008291580132
# -0.5811337726772265   0.04697185284995373
# -0.5327325467977466   0.048401225879479974
# -0.48326282620635846   0.049469720591388176
# -0.4330948874817023   0.05016793872465617
# -0.38259741883074994   0.050497468650952324
# -0.3321262041607977   0.05047121466995224
# -0.2820133546129682   0.05011284954782947
# -0.23255788752996603   0.049455467083002184
# -0.18401826740705327   0.048539620122912776
# -0.1366072690445586   0.04741099836249466
# -0.09048925027604994   0.04611801876850867
# -0.04577967741528463   0.04470957286076531
# -0.0025465640789423954   0.043233113336342235
# 0.03918662221316684   0.04173318629210924
# 0.07943706402127534   0.0402504418081085
# 0.11825816077043269   0.038821096749157354
# 0.15573494538771268   0.03747678461727998
# 0.19197965326741478   0.03624470787970211
# 0.22712765791323405   0.03514800464581926
# 0.26133390663108036   0.03420624871784633
# 0.29476992153370485   0.03343601490262449
# 0.3276213776010583   0.03285145606735348
# 0.36008622964201514   0.03246485204095686
# 0.39237333119375256   0.03228710155173744
# 0.4247014674650928   0.03232813627134025
# 0.4572987080611719   0.03259724059607911
# 0.49040197031675425   0.033103262255582334
# ------------------------
# DONE
# # steps taken:  115
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
